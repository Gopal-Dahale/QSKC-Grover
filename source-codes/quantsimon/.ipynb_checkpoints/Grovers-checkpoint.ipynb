# %%
def itera(qc):
    for i in range(6):
        if(pt[i] == 1):
            qc.x(l[i])
    
    qc.ccx(l[1],l[2],l[3])
    qc.cx(l[0],l[3])
    qc.cx(k[0],l[3])
    
    qc.ccx(l[2],l[0],l[4])
    qc.cx(l[1],l[4])
    qc.cx(k[1],l[4])

    qc.ccx(l[0],l[1],l[5])
    qc.cx(l[2],l[5])
    qc.cx(k[2],l[5])

    qc.ccx(l[4],l[5],l[0])
    qc.cx(l[3],l[0])
    qc.cx(k[3],l[0])

    qc.ccx(l[5],l[3],l[1])
    qc.cx(l[4],l[1])
    qc.cx(k[4],l[1])

    qc.ccx(l[3],l[4],l[2])
    qc.cx(l[5],l[2])
    qc.cx(k[5],l[2])

    qc.x(k[2])
        
    qc.cx(k[4],k[0])
    qc.cx(k[5],k[0])

    qc.cx(k[5],k[1])
    qc.cx(k[3],k[1])

    qc.cx(k[3],k[2])
    qc.cx(k[4],k[2])

    qc.x(k[5])

    qc.cx(k[1],k[3])
    qc.cx(k[2],k[3])

    qc.cx(k[2],k[4])
    qc.cx(k[0],k[4])

    qc.cx(k[0],k[5])
    qc.cx(k[1],k[5])

    qc.ccx(l[1],l[2],l[3])
    qc.cx(l[0],l[3])
    qc.cx(k[0],l[3])

    qc.ccx(l[2],l[0],l[4])
    qc.cx(l[1],l[4])
    qc.cx(k[1],l[4])

    qc.ccx(l[0],l[1],l[5])
    qc.cx(l[2],l[5])
    qc.cx(k[2],l[5])

    qc.ccx(l[4],l[5],l[0])
    qc.cx(l[3],l[0])
    qc.cx(k[3],l[0])

    qc.ccx(l[5],l[3],l[1])
    qc.cx(l[4],l[1])
    qc.cx(k[4],l[1])

    qc.ccx(l[3],l[4],l[2])
    qc.cx(l[5],l[2])
    qc.cx(k[5],l[2])
    
    
def invitera(qc):
    qc.ccx(l[3],l[4],l[2])
    qc.cx(l[5],l[2])
    qc.cx(k[5],l[2])
    
    qc.ccx(l[5],l[3],l[1])
    qc.cx(l[4],l[1])
    qc.cx(k[4],l[1])
    
    qc.ccx(l[4],l[5],l[0])
    qc.cx(l[3],l[0])
    qc.cx(k[3],l[0])
    
    qc.ccx(l[0],l[1],l[5])
    qc.cx(l[2],l[5])
    qc.cx(k[2],l[5])
    
    qc.ccx(l[2],l[0],l[4])
    qc.cx(l[1],l[4])
    qc.cx(k[1],l[4])
    
    qc.ccx(l[1],l[2],l[3])
    qc.cx(l[0],l[3])
    qc.cx(k[0],l[3])
    
    qc.cx(k[0],k[5])
    qc.cx(k[1],k[5])
    
    qc.cx(k[2],k[4])
    qc.cx(k[0],k[4])
    
    qc.cx(k[1],k[3])
    qc.cx(k[2],k[3])
    
    qc.x(k[5])
    
    qc.cx(k[3],k[2])
    qc.cx(k[4],k[2])
    
    qc.cx(k[5],k[1])
    qc.cx(k[3],k[1])
    
    qc.cx(k[4],k[0])
    qc.cx(k[5],k[0])
    
    qc.x(k[2])
    
    qc.ccx(l[3],l[4],l[2])
    qc.cx(l[5],l[2])
    qc.cx(k[5],l[2])
    
    qc.ccx(l[5],l[3],l[1])
    qc.cx(l[4],l[1])
    qc.cx(k[4],l[1])
    
    qc.ccx(l[4],l[5],l[0])
    qc.cx(l[3],l[0])
    qc.cx(k[3],l[0])
    
    qc.ccx(l[0],l[1],l[5])
    qc.cx(l[2],l[5])
    qc.cx(k[2],l[5])
    
    qc.ccx(l[2],l[0],l[4])
    qc.cx(l[1],l[4])
    qc.cx(k[1],l[4])
    
    qc.ccx(l[1],l[2],l[3])
    qc.cx(l[0],l[3])
    qc.cx(k[0],l[3])
    
    for i in range(6):
        if(pt[i] == 1):
            qc.x(l[i])
        
from qiskit import *
# %matplotlib inline
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, Aer, execute
from qiskit.tools.visualization import circuit_drawer
from qiskit.visualization import plot_histogram
import Our_Qiskit_Functions as oq
simulator = Aer.get_backend('qasm_simulator')

l = QuantumRegister(6, name='l')
k = QuantumRegister(6, name='k')
trg = QuantumRegister(1, name = 'trg')
anc = QuantumRegister(4, name = 'anc')
c = ClassicalRegister(6, name='c')

qc = QuantumCircuit(l,k,trg,anc,c)

pt = [0,1,1,1,0,1]

for i in range(6):
    qc.h(k[i])
    
qc.x(trg[0])

for j in range(6):
    itera(qc)
    oq.Grover_Oracle([0,1,1,1,1,1], qc, l, trg, anc)
    invitera(qc)

    oq.Grover_Diffusion([0,0,0,0,0,0], qc, k, trg, anc)


for i in range(6):
    qc.measure(k[i],c[i])
        
job = execute(qc, simulator, shots=1024)
result = job.result()
counts = result.get_counts(qc)
print(counts)
plot_histogram(counts)
# Out:
# {'000001': 4, '100000': 9, '101110': 6, '101101': 10, '011110': 7, '001000': 5, '101111': 7, '000110': 7, '111111': 4, '100010': 7, '001101': 7, '010100': 2, '011000': 7, '100001': 3, '100101': 4, '110101': 5, '100111': 5, '011101': 7, '101001': 7, '101100': 12, '000100': 5, '010001': 6, '111101': 5, '011001': 10, '000011': 7, '000111': 282, '001001': 7, '110111': 9, '111000': 10, '111010': 14, '111001': 10, '100110': 13, '110000': 6, '001010': 9, '000010': 5, '100100': 8, '110001': 8, '011100': 280, '010010': 6, '001111': 12, '111110': 10, '011010': 5, '101010': 10, '111011': 8, '001100': 7, '010000': 9, '010101': 10, '100011': 9, '010111': 9, '101011': 8, '000000': 9, '001011': 9, '110011': 2, '111100': 7, '010011': 7, '000101': 11, '110110': 7, '011011': 5, '110010': 6, '010110': 10, '011111': 8, '101000': 6, '001110': 9, '110100': 6}

# %%
def itera(qc):
    for i in range(6):
        if(pt[i] == 1):
            qc.x(l[i])
    
    qc.ccx(l[1],l[2],l[3])
    qc.cx(l[0],l[3])
    qc.cx(k[0],l[3])
    
    qc.ccx(l[2],l[0],l[4])
    qc.cx(l[1],l[4])
    qc.cx(k[1],l[4])

    qc.ccx(l[0],l[1],l[5])
    qc.cx(l[2],l[5])
    qc.cx(k[2],l[5])

    qc.ccx(l[4],l[5],l[0])
    qc.cx(l[3],l[0])
    qc.cx(k[3],l[0])

    qc.ccx(l[5],l[3],l[1])
    qc.cx(l[4],l[1])
    qc.cx(k[4],l[1])

    qc.ccx(l[3],l[4],l[2])
    qc.cx(l[5],l[2])
    qc.cx(k[5],l[2])

    qc.x(k[2])
        
    qc.cx(k[4],k[0])
    qc.cx(k[5],k[0])

    qc.cx(k[5],k[1])
    qc.cx(k[3],k[1])

    qc.cx(k[3],k[2])
    qc.cx(k[4],k[2])

    qc.x(k[5])

    qc.cx(k[1],k[3])
    qc.cx(k[2],k[3])

    qc.cx(k[2],k[4])
    qc.cx(k[0],k[4])

    qc.cx(k[0],k[5])
    qc.cx(k[1],k[5])

    qc.ccx(l[1],l[2],l[3])
    qc.cx(l[0],l[3])
    qc.cx(k[0],l[3])

    qc.ccx(l[2],l[0],l[4])
    qc.cx(l[1],l[4])
    qc.cx(k[1],l[4])

    qc.ccx(l[0],l[1],l[5])
    qc.cx(l[2],l[5])
    qc.cx(k[2],l[5])

    qc.ccx(l[4],l[5],l[0])
    qc.cx(l[3],l[0])
    qc.cx(k[3],l[0])

    qc.ccx(l[5],l[3],l[1])
    qc.cx(l[4],l[1])
    qc.cx(k[4],l[1])

    qc.ccx(l[3],l[4],l[2])
    qc.cx(l[5],l[2])
    qc.cx(k[5],l[2])
    
    
def invitera(qc):
    qc.ccx(l[3],l[4],l[2])
    qc.cx(l[5],l[2])
    qc.cx(k[5],l[2])
    
    qc.ccx(l[5],l[3],l[1])
    qc.cx(l[4],l[1])
    qc.cx(k[4],l[1])
    
    qc.ccx(l[4],l[5],l[0])
    qc.cx(l[3],l[0])
    qc.cx(k[3],l[0])
    
    qc.ccx(l[0],l[1],l[5])
    qc.cx(l[2],l[5])
    qc.cx(k[2],l[5])
    
    qc.ccx(l[2],l[0],l[4])
    qc.cx(l[1],l[4])
    qc.cx(k[1],l[4])
    
    qc.ccx(l[1],l[2],l[3])
    qc.cx(l[0],l[3])
    qc.cx(k[0],l[3])
    
    qc.cx(k[0],k[5])
    qc.cx(k[1],k[5])
    
    qc.cx(k[2],k[4])
    qc.cx(k[0],k[4])
    
    qc.cx(k[1],k[3])
    qc.cx(k[2],k[3])
    
    qc.x(k[5])
    
    qc.cx(k[3],k[2])
    qc.cx(k[4],k[2])
    
    qc.cx(k[5],k[1])
    qc.cx(k[3],k[1])
    
    qc.cx(k[4],k[0])
    qc.cx(k[5],k[0])
    
    qc.x(k[2])
    
    qc.ccx(l[3],l[4],l[2])
    qc.cx(l[5],l[2])
    qc.cx(k[5],l[2])
    
    qc.ccx(l[5],l[3],l[1])
    qc.cx(l[4],l[1])
    qc.cx(k[4],l[1])
    
    qc.ccx(l[4],l[5],l[0])
    qc.cx(l[3],l[0])
    qc.cx(k[3],l[0])
    
    qc.ccx(l[0],l[1],l[5])
    qc.cx(l[2],l[5])
    qc.cx(k[2],l[5])
    
    qc.ccx(l[2],l[0],l[4])
    qc.cx(l[1],l[4])
    qc.cx(k[1],l[4])
    
    qc.ccx(l[1],l[2],l[3])
    qc.cx(l[0],l[3])
    qc.cx(k[0],l[3])
    
    for i in range(6):
        if(pt[i] == 1):
            qc.x(l[i])
        
from qiskit import *
# %matplotlib inline
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, Aer, execute
from qiskit.tools.visualization import circuit_drawer
from qiskit.visualization import plot_histogram
import Our_Qiskit_Functions as oq
simulator = Aer.get_backend('qasm_simulator')

l = QuantumRegister(6, name='l')
k = QuantumRegister(6, name='k')
trg = QuantumRegister(1, name = 'trg')
anc = QuantumRegister(4, name = 'anc')
c = ClassicalRegister(6, name='c')

qc = QuantumCircuit(l,k,trg,anc,c)

pt = [0,0,1,1,0,1]

for i in range(6):
    qc.h(k[i])
    
qc.x(trg[0])

for j in range(6):
    itera(qc)
    oq.Grover_Oracle([1,1,0,0,1,1], qc, l, trg, anc)
    invitera(qc)

    oq.Grover_Diffusion([0,0,0,0,0,0], qc, k, trg, anc)


for i in range(6):
    qc.measure(k[i],c[i])
        
job = execute(qc, simulator, shots=1024)
result = job.result()
counts = result.get_counts(qc)
print(counts)
plot_histogram(counts)
# Out:
# {'101110': 4, '011101': 4, '011111': 3, '101101': 6, '000110': 4, '111011': 2, '001100': 7, '010000': 6, '101100': 7, '110101': 7, '110000': 6, '111001': 6, '100110': 7, '000111': 8, '010101': 17, '001111': 5, '010010': 10, '100111': 9, '001110': 5, '101000': 9, '101001': 5, '000100': 10, '010001': 6, '111101': 8, '011001': 8, '100101': 8, '100001': 8, '110011': 8, '111100': 12, '110110': 7, '011011': 5, '001010': 10, '000010': 12, '100100': 281, '000000': 2, '101011': 9, '110010': 10, '010110': 11, '111111': 4, '100010': 7, '011110': 7, '001101': 10, '000001': 8, '000101': 3, '010011': 7, '110100': 6, '001011': 8, '100000': 10, '011000': 3, '010100': 10, '100011': 6, '010111': 9, '111000': 8, '111010': 11, '001001': 10, '110111': 7, '011100': 280, '110001': 10, '001000': 12, '000011': 10, '101010': 5, '111110': 10, '011010': 5, '101111': 6}
