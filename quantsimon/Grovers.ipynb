# %%
def itera(qc):
    for i in range(6):
        if(pt[i] == 1):
            qc.x(l[i])
    
    qc.ccx(l[1],l[2],l[3])
    qc.cx(l[0],l[3])
    qc.cx(k[0],l[3])
    
    qc.ccx(l[2],l[0],l[4])
    qc.cx(l[1],l[4])
    qc.cx(k[1],l[4])

    qc.ccx(l[0],l[1],l[5])
    qc.cx(l[2],l[5])
    qc.cx(k[2],l[5])

    qc.ccx(l[4],l[5],l[0])
    qc.cx(l[3],l[0])
    qc.cx(k[3],l[0])

    qc.ccx(l[5],l[3],l[1])
    qc.cx(l[4],l[1])
    qc.cx(k[4],l[1])

    qc.ccx(l[3],l[4],l[2])
    qc.cx(l[5],l[2])
    qc.cx(k[5],l[2])

    qc.x(k[2])
        
    qc.cx(k[4],k[0])
    qc.cx(k[5],k[0])

    qc.cx(k[5],k[1])
    qc.cx(k[3],k[1])

    qc.cx(k[3],k[2])
    qc.cx(k[4],k[2])

    qc.x(k[5])

    qc.cx(k[1],k[3])
    qc.cx(k[2],k[3])

    qc.cx(k[2],k[4])
    qc.cx(k[0],k[4])

    qc.cx(k[0],k[5])
    qc.cx(k[1],k[5])

    qc.ccx(l[1],l[2],l[3])
    qc.cx(l[0],l[3])
    qc.cx(k[0],l[3])

    qc.ccx(l[2],l[0],l[4])
    qc.cx(l[1],l[4])
    qc.cx(k[1],l[4])

    qc.ccx(l[0],l[1],l[5])
    qc.cx(l[2],l[5])
    qc.cx(k[2],l[5])

    qc.ccx(l[4],l[5],l[0])
    qc.cx(l[3],l[0])
    qc.cx(k[3],l[0])

    qc.ccx(l[5],l[3],l[1])
    qc.cx(l[4],l[1])
    qc.cx(k[4],l[1])

    qc.ccx(l[3],l[4],l[2])
    qc.cx(l[5],l[2])
    qc.cx(k[5],l[2])
    
    
def invitera(qc):
    qc.ccx(l[3],l[4],l[2])
    qc.cx(l[5],l[2])
    qc.cx(k[5],l[2])
    
    qc.ccx(l[5],l[3],l[1])
    qc.cx(l[4],l[1])
    qc.cx(k[4],l[1])
    
    qc.ccx(l[4],l[5],l[0])
    qc.cx(l[3],l[0])
    qc.cx(k[3],l[0])
    
    qc.ccx(l[0],l[1],l[5])
    qc.cx(l[2],l[5])
    qc.cx(k[2],l[5])
    
    qc.ccx(l[2],l[0],l[4])
    qc.cx(l[1],l[4])
    qc.cx(k[1],l[4])
    
    qc.ccx(l[1],l[2],l[3])
    qc.cx(l[0],l[3])
    qc.cx(k[0],l[3])
    
    qc.cx(k[0],k[5])
    qc.cx(k[1],k[5])
    
    qc.cx(k[2],k[4])
    qc.cx(k[0],k[4])
    
    qc.cx(k[1],k[3])
    qc.cx(k[2],k[3])
    
    qc.x(k[5])
    
    qc.cx(k[3],k[2])
    qc.cx(k[4],k[2])
    
    qc.cx(k[5],k[1])
    qc.cx(k[3],k[1])
    
    qc.cx(k[4],k[0])
    qc.cx(k[5],k[0])
    
    qc.x(k[2])
    
    qc.ccx(l[3],l[4],l[2])
    qc.cx(l[5],l[2])
    qc.cx(k[5],l[2])
    
    qc.ccx(l[5],l[3],l[1])
    qc.cx(l[4],l[1])
    qc.cx(k[4],l[1])
    
    qc.ccx(l[4],l[5],l[0])
    qc.cx(l[3],l[0])
    qc.cx(k[3],l[0])
    
    qc.ccx(l[0],l[1],l[5])
    qc.cx(l[2],l[5])
    qc.cx(k[2],l[5])
    
    qc.ccx(l[2],l[0],l[4])
    qc.cx(l[1],l[4])
    qc.cx(k[1],l[4])
    
    qc.ccx(l[1],l[2],l[3])
    qc.cx(l[0],l[3])
    qc.cx(k[0],l[3])
    
    for i in range(6):
        if(pt[i] == 1):
            qc.x(l[i])
        
from qiskit import *
# %matplotlib inline
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, Aer, execute
from qiskit.tools.visualization import circuit_drawer
from qiskit.visualization import plot_histogram
import Our_Qiskit_Functions as oq
simulator = Aer.get_backend('qasm_simulator')

l = QuantumRegister(6, name='l')
k = QuantumRegister(6, name='k')
trg = QuantumRegister(1, name = 'trg')
anc = QuantumRegister(4, name = 'anc')
c = ClassicalRegister(6, name='c')

qc = QuantumCircuit(l,k,trg,anc,c)

pt = [0,1,1,1,0,1]

for i in range(6):
    qc.h(k[i])
    
qc.x(trg[0])

for j in range(6):
    itera(qc)
    oq.Grover_Oracle([0,1,1,1,1,1], qc, l, trg, anc)
    invitera(qc)

    oq.Grover_Diffusion([0,0,0,0,0,0], qc, k, trg, anc)


for i in range(6):
    qc.measure(k[i],c[i])
        
job = execute(qc, simulator, shots=1024)
result = job.result()
counts = result.get_counts(qc)
print(counts)
plot_histogram(counts)
# Out:
# {'000001': 6, '011110': 3, '101101': 11, '101001': 8, '000101': 6, '010011': 8, '010110': 2, '110010': 8, '000110': 7, '111101': 9, '011001': 8, '100000': 8, '100100': 7, '111010': 14, '001101': 14, '011111': 8, '110101': 12, '111000': 7, '100110': 5, '111001': 12, '011000': 6, '010100': 9, '011101': 11, '110001': 7, '011100': 260, '000011': 13, '010001': 10, '000100': 9, '001011': 11, '000111': 275, '100001': 8, '100101': 12, '001110': 6, '101000': 10, '100111': 10, '100010': 9, '111111': 3, '110110': 11, '011011': 10, '000000': 7, '101011': 9, '001010': 12, '000010': 15, '010101': 5, '001100': 7, '111011': 6, '010000': 5, '101111': 8, '001111': 1, '010010': 9, '101100': 5, '001000': 6, '111100': 4, '110011': 12, '100011': 5, '010111': 2, '110111': 7, '001001': 8, '110000': 6, '111110': 4, '101010': 8, '011010': 7, '101110': 6, '110100': 7}

# %%
def itera(qc):
    for i in range(6):
        if(pt[i] == 1):
            qc.x(l[i])
    
    qc.ccx(l[1],l[2],l[3])
    qc.cx(l[0],l[3])
    qc.cx(k[0],l[3])
    
    qc.ccx(l[2],l[0],l[4])
    qc.cx(l[1],l[4])
    qc.cx(k[1],l[4])

    qc.ccx(l[0],l[1],l[5])
    qc.cx(l[2],l[5])
    qc.cx(k[2],l[5])

    qc.ccx(l[4],l[5],l[0])
    qc.cx(l[3],l[0])
    qc.cx(k[3],l[0])

    qc.ccx(l[5],l[3],l[1])
    qc.cx(l[4],l[1])
    qc.cx(k[4],l[1])

    qc.ccx(l[3],l[4],l[2])
    qc.cx(l[5],l[2])
    qc.cx(k[5],l[2])

    qc.x(k[2])
        
    qc.cx(k[4],k[0])
    qc.cx(k[5],k[0])

    qc.cx(k[5],k[1])
    qc.cx(k[3],k[1])

    qc.cx(k[3],k[2])
    qc.cx(k[4],k[2])

    qc.x(k[5])

    qc.cx(k[1],k[3])
    qc.cx(k[2],k[3])

    qc.cx(k[2],k[4])
    qc.cx(k[0],k[4])

    qc.cx(k[0],k[5])
    qc.cx(k[1],k[5])

    qc.ccx(l[1],l[2],l[3])
    qc.cx(l[0],l[3])
    qc.cx(k[0],l[3])

    qc.ccx(l[2],l[0],l[4])
    qc.cx(l[1],l[4])
    qc.cx(k[1],l[4])

    qc.ccx(l[0],l[1],l[5])
    qc.cx(l[2],l[5])
    qc.cx(k[2],l[5])

    qc.ccx(l[4],l[5],l[0])
    qc.cx(l[3],l[0])
    qc.cx(k[3],l[0])

    qc.ccx(l[5],l[3],l[1])
    qc.cx(l[4],l[1])
    qc.cx(k[4],l[1])

    qc.ccx(l[3],l[4],l[2])
    qc.cx(l[5],l[2])
    qc.cx(k[5],l[2])
    
    
def invitera(qc):
    qc.ccx(l[3],l[4],l[2])
    qc.cx(l[5],l[2])
    qc.cx(k[5],l[2])
    
    qc.ccx(l[5],l[3],l[1])
    qc.cx(l[4],l[1])
    qc.cx(k[4],l[1])
    
    qc.ccx(l[4],l[5],l[0])
    qc.cx(l[3],l[0])
    qc.cx(k[3],l[0])
    
    qc.ccx(l[0],l[1],l[5])
    qc.cx(l[2],l[5])
    qc.cx(k[2],l[5])
    
    qc.ccx(l[2],l[0],l[4])
    qc.cx(l[1],l[4])
    qc.cx(k[1],l[4])
    
    qc.ccx(l[1],l[2],l[3])
    qc.cx(l[0],l[3])
    qc.cx(k[0],l[3])
    
    qc.cx(k[0],k[5])
    qc.cx(k[1],k[5])
    
    qc.cx(k[2],k[4])
    qc.cx(k[0],k[4])
    
    qc.cx(k[1],k[3])
    qc.cx(k[2],k[3])
    
    qc.x(k[5])
    
    qc.cx(k[3],k[2])
    qc.cx(k[4],k[2])
    
    qc.cx(k[5],k[1])
    qc.cx(k[3],k[1])
    
    qc.cx(k[4],k[0])
    qc.cx(k[5],k[0])
    
    qc.x(k[2])
    
    qc.ccx(l[3],l[4],l[2])
    qc.cx(l[5],l[2])
    qc.cx(k[5],l[2])
    
    qc.ccx(l[5],l[3],l[1])
    qc.cx(l[4],l[1])
    qc.cx(k[4],l[1])
    
    qc.ccx(l[4],l[5],l[0])
    qc.cx(l[3],l[0])
    qc.cx(k[3],l[0])
    
    qc.ccx(l[0],l[1],l[5])
    qc.cx(l[2],l[5])
    qc.cx(k[2],l[5])
    
    qc.ccx(l[2],l[0],l[4])
    qc.cx(l[1],l[4])
    qc.cx(k[1],l[4])
    
    qc.ccx(l[1],l[2],l[3])
    qc.cx(l[0],l[3])
    qc.cx(k[0],l[3])
    
    for i in range(6):
        if(pt[i] == 1):
            qc.x(l[i])
        
from qiskit import *
# %matplotlib inline
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, Aer, execute
from qiskit.tools.visualization import circuit_drawer
from qiskit.visualization import plot_histogram
import Our_Qiskit_Functions as oq
simulator = Aer.get_backend('qasm_simulator')

l = QuantumRegister(6, name='l')
k = QuantumRegister(6, name='k')
trg = QuantumRegister(1, name = 'trg')
anc = QuantumRegister(4, name = 'anc')
c = ClassicalRegister(6, name='c')

qc = QuantumCircuit(l,k,trg,anc,c)

pt = [0,0,1,1,0,1]

for i in range(6):
    qc.h(k[i])
    
qc.x(trg[0])

for j in range(6):
    itera(qc)
    oq.Grover_Oracle([1,1,0,0,1,1], qc, l, trg, anc)
    invitera(qc)

    oq.Grover_Diffusion([0,0,0,0,0,0], qc, k, trg, anc)


for i in range(6):
    qc.measure(k[i],c[i])
        
job = execute(qc, simulator, shots=1024)
result = job.result()
counts = result.get_counts(qc)
print(counts)
plot_histogram(counts)
# Out:
# {'101110': 4, '011101': 4, '011111': 3, '101101': 6, '000110': 4, '111011': 2, '001100': 7, '010000': 6, '101100': 7, '110101': 7, '110000': 6, '111001': 6, '100110': 7, '000111': 8, '010101': 17, '001111': 5, '010010': 10, '100111': 9, '001110': 5, '101000': 9, '101001': 5, '000100': 10, '010001': 6, '111101': 8, '011001': 8, '100101': 8, '100001': 8, '110011': 8, '111100': 12, '110110': 7, '011011': 5, '001010': 10, '000010': 12, '100100': 281, '000000': 2, '101011': 9, '110010': 10, '010110': 11, '111111': 4, '100010': 7, '011110': 7, '001101': 10, '000001': 8, '000101': 3, '010011': 7, '110100': 6, '001011': 8, '100000': 10, '011000': 3, '010100': 10, '100011': 6, '010111': 9, '111000': 8, '111010': 11, '001001': 10, '110111': 7, '011100': 280, '110001': 10, '001000': 12, '000011': 10, '101010': 5, '111110': 10, '011010': 5, '101111': 6}
